# %%
import matplotlib.pyplot as plt
import numpy as np
import generate_toy as gt
import seaborn as sns

figsize = (12, 6)
color_palette = sns.color_palette("Dark2")

def plot_examples(func, params, lims, step):
    plt.figure(figsize=figsize)
    for i in range(len(params)):
        X = np.arange(lims[i][0], lims[i][1], step)
        y = func(X, *params[i])
        plt.scatter(X, y, color=color_palette[i], label=f'Example {i} : {params[i]}')
    plt.legend()

# %% [markdown]
# # Polynomial equation

# %%
step = .1
example_parameters = [[-2, 2, 0],
                      [2, 0, -2],
                      [2, 2, 2],
                      [-2, -2, -2]]

X_limits = [[-2, 2],
            [-2, 2],
            [-0, 1],
            [-2, -1]]

plot_examples(gt.func_poly, example_parameters, X_limits, step)

# %% [markdown]
# # Gaussian equation

# %%
step = .1
example_parameters = [[0, 2, 2],
                      [2, 0, .5],
                      [.5, .5, .5],
                      [2, -.5, .5]]

X_limits = [[-2, 2],
            [-2, 2],
            [-2, .5],
            [-.5, 2]]

plot_examples(gt.func_gaussian, example_parameters, X_limits, step)

# %% [markdown]
# # Friedman equation #1
# ### Impossible to visualise, just making sure the code runs

# %%
npoints = 100
# Points here are (and should be) uniformly sampled between 0 and 1
X1 = np.random.random_sample(npoints)
X2 = np.random.random_sample(npoints)
X3 = np.random.random_sample(npoints)
X4 = np.random.random_sample(npoints)
X5 = np.random.random_sample(npoints)

example_parameters = [[2, 2, 2, 0],
                      [2, 2, 0, 2],
                      [2, 0, 2, 2],
                      [0, 2, 2, 2]]

X = np.array(list(zip(X1, X2, X3, X4, X5)))
y = gt.func_fried1(X, *example_parameters[0])
y
# Out:
# array([4.08569346, 6.90344863, 4.11749603, 3.56706928, 3.48262427,
#        6.35325587, 7.56568037, 5.95184919, 3.90131204, 6.76710303,
#        5.63000673, 3.80950956, 6.93627269, 4.94547518, 8.36266958,
#        6.69762528, 4.71000789, 6.80842048, 8.04989489, 2.88572473,
#        2.74708589, 5.95473138, 7.02407732, 8.12922725, 6.82303871,
#        2.81062491, 3.23523177, 4.03211675, 2.91008591, 3.88249496,
#        6.62504595, 5.17951443, 3.27120202, 8.27813917, 5.29581406,
#        6.22067405, 4.3042903 , 4.14830591, 3.63211229, 3.96215365,
#        4.56309578, 3.37175665, 2.65906971, 6.89442532, 7.11772921,
#        4.03128882, 5.40574645, 7.72071414, 3.39189796, 3.19702967,
#        6.67437139, 3.39709886, 2.69036151, 8.51051046, 5.97711789,
#        7.79987397, 6.86466939, 6.07429957, 2.42288971, 7.82502195,
#        4.83960835, 5.96558013, 7.91276639, 4.24226724, 2.38041321,
#        4.53446081, 6.87239306, 5.84605555, 4.88182469, 5.18733496,
#        8.66577735, 4.65963901, 3.88579251, 8.65525827, 3.41440645,
#        3.94774419, 8.72510969, 5.43225063, 3.68105261, 5.08357888,
#        5.92054551, 4.0029217 , 4.45808638, 8.87530677, 9.12715184,
#        3.68969617, 7.65637035, 2.31729864, 3.25024656, 6.82838231,
#        4.29834689, 5.68372302, 7.60681435, 3.18659305, 6.63846253,
#        7.31802214, 3.88386546, 4.19097775, 6.9162226 , 4.02134021])

# %% [markdown]
# # Friedman equation #2
# ### Impossible to visualise, just making sure the code runs

# %%
npoints = 100
X1 = np.random.uniform(low=0, high=100, size=npoints)
X2 = np.random.uniform(low=40*np.pi, high=560*np.pi, size=npoints)
X3 = np.random.uniform(low=0, high=1, size=npoints)
X4 = np.random.uniform(low=1, high=11, size=npoints)

example_parameters = [[2, 2, 2, 0],
                      [2, 2, 0, 2],
                      [2, 0, 2, 2],
                      [0, 2, 2, 2]]

X = np.array(list(zip(X1, X2, X3, X4)))
y = gt.func_fried2(X, *example_parameters[0])
y
# Out:
# array([141.09957901,  70.29716102, 123.84380142, 107.53741392,
#        201.5481216 , 161.78705716, 273.33792527,  79.73152571,
#        279.82098484, 251.48267275, 193.17686792, 259.83279364,
#         35.43530067,  72.4234835 , 224.95537955, 145.55242345,
#        180.6273084 , 177.10287106, 135.99313785, 163.09502908,
#        182.48237541, 203.22828576, 171.01950074,   6.94823889,
#        115.3409371 , 197.75641583, 174.08958726, 161.92874905,
#        151.8723462 , 245.90747884,  95.06431875, 195.3261153 ,
#         25.13265865, 183.60929617,  88.93615766, 223.77508189,
#         53.73070051, 197.89249071, 175.78221661, 227.3727875 ,
#         11.30533184, 195.08313801, 111.69320677,  41.77973987,
#        115.5344694 ,  37.33125459, 164.5425829 ,   7.05836584,
#        179.24943365, 228.3786626 , 232.78606243, 202.47657506,
#         36.60903088,  59.08708032, 206.05946124,  26.74434602,
#        255.9595863 , 276.39126311, 262.315398  ,  93.92568437,
#        166.69114144,  23.28779271,  44.63218929, 171.47474148,
#        237.07404433,  94.63098696, 107.65424807, 277.85702812,
#        192.65072073,   5.93324341, 196.25661018, 218.96905389,
#        100.29752356, 261.13443569, 242.93062682, 243.91458833,
#        226.4351284 , 134.72276234,  41.39856621, 158.9027143 ,
#         73.02966776, 182.07461048, 104.48007387, 226.9866581 ,
#         76.27082968, 127.05471084, 213.13841246, 140.91689472,
#        253.11664455,  47.39813995, 262.1170384 , 249.02455069,
#        202.03060999,  30.22205008, 205.97516605,  53.35458741,
#        248.30531694, 277.36366156, 174.04943888,  74.79147274])
