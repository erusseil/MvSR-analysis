# %%
import sys, os
import pandas as pd
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
import astropy
import shutil
import pyoperon as Operon
from iminuit import Minuit
from iminuit.cost import LeastSquares
import seaborn as sns

sys.path.append('../')
import mvsr as mvsr
import analysis as ana

# %%
pd.read_csv(f"data_market/NASDAQ_AAPL_2010_5m.csv")
# Out:
#           Date   Open   High    Low  Close  Volume
# 0     10110900  42.14  42.15  42.12  42.12    5235
# 1     10110905  42.12  42.13  42.11  42.12    7441
# 2     10110910  42.12  42.14  42.12  42.12    4268
# 3     10110915  42.12  42.12  42.11  42.12    4012
# 4     10110920  42.11  42.12  42.09  42.10   13081
# ...        ...    ...    ...    ...    ...     ...
# 2009  11081630  45.51  45.54  45.51  45.54    3561
# 2010  11081635  45.53  45.53  45.49  45.50    4841
# 2011  11081640  45.50  45.54  45.50  45.53    5244
# 2012  11081645  45.54  45.54  45.50  45.51  140566
# 2013  11081650  45.52  45.52  45.50  45.52    1160
#
# [2014 rows x 6 columns]

# %%
folder = "data_market/examples"

# Delete and recreate folder
if os.path.exists(f"{folder}"):
    shutil.rmtree(f"{folder}")
os.makedirs(f"{folder}")

binage = [100, 200, 100, 100]
files = ['Apple','NASDAQ_AAPL_2010_5m','Bitcoin','Microsoft']

for i in range(len(files)):
    data = pd.read_csv(f"data_market/{files[i]}.csv")
    data['Open'] = data['Open']/data['Open'].max()
    diffs = (np.array(data['Open'][1:]) - np.array(data['Open'][:-1]))

    hist, bins = np.histogram(diffs, bins=binage[i]);
    x, y = bins[:-1], hist

    mask = y > 10
    x, y = x[mask], y[mask]
    y = np.log(y)

    #mask2 = y!=0
    #x, y = x[mask2], y[mask2]

    plt.scatter(x, y)
    ana.save_2D_example(x, y, f'{folder}/example{i}.csv')

# %%
agg_best_str, all_best_str = mvsr.MultiViewSR(folder, maxL=12, maxD=3, generations=1000, seed=8,
                                              OperationSet=Operon.NodeType.Pow|Operon.NodeType.Abs, verbose=False, explicit_params=False)

func, func_str, initial_guess = ana.convert_string_to_func(agg_best_str, 1)
print("f(X1) =", func_str)
# Out:
# f(X1) = (A - B*X1)**((C*Abs(X1))**(D*Abs(X1)))

# %%
ana.refit_and_plot(folder, func, func_str, initial_guess,
                   [-0.05, 0.05], [-1, 10],
                   ['Daily market evolution (%)', ''],
                   folder[:folder.find('/')])

# %% [markdown]
# # ______________________________________________________________________________

# %%
folder_simplified = "data_market/normalized_examples"

# Delete and recreate folder
if os.path.exists(f"{folder_simplified}"):
    shutil.rmtree(f"{folder_simplified}")
os.makedirs(f"{folder_simplified}")

files = ['Apple','Microsoft','Bitcoin','Nasdaq']

for i in range(len(files)):
    data = pd.read_csv(f"data_market/{files[i]}.csv")
    diffs = 100 * (np.array(data['Open'][:-1]) - np.array(data['Open'][1:])) / np.array(data['Open'][:-1])

    diffs = diffs[(diffs>-10)&(diffs<10)]
    hist, bins = np.histogram(diffs, bins=50);
    x, y = bins[:-1], hist
    y = y/y.max()

    plt.scatter(x, y)
    ana.save_2D_example(x, y, f'{folder_simplified}/example{i}.csv')

# %%
def simplified(X, A, B, C):
    return np.exp(A*X[0])/(-B*X[0] + np.exp(C*X[0]))

simplified_str = 'max(X1)*exp(A*X1)/(-B*X1 + exp(C*X1))'
simplified_guess =  {'A': 1.2,'B': 0.35,'C': 2.5}


ana.refit_and_plot(folder_simplified, simplified, simplified_str, simplified_guess,
                   [-7, 7], [-.1, 1.3],
                   ['Daily market evolution (%)', ''],
                   "normalized_data_market")

# %%
folder_test = "data_market/examples_test"

# Delete and recreate folder
if os.path.exists(f"{folder_test}"):
    shutil.rmtree(f"{folder_test}")
os.makedirs(f"{folder_test}")

files = ['CAC40', 'Nasdaq']

for i in range(len(files)):
    data = pd.read_csv(f"data_market/{files[i]}.csv")
    diffs = 100 * (np.array(data['Open'][:-1]) - np.array(data['Open'][1:])) / np.array(data['Open'][:-1])

    diffs = diffs[(diffs>-10)&(diffs<10)]
    hist, bins = np.histogram(diffs, bins=50);
    x, y = bins[:-1], hist

    ana.save_2D_example(x, y, f'{folder_test}/example{i}.csv')

ana.refit_and_plot(folder_test, func, func_str, initial_guess,
                   [-7, 7], [-30, 1500],
                   ['Daily market evolution (%)', ''],
                   folder[:folder.find('/')])
